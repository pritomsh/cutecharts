# %%
# import libraries
import pandas as pd
import cutecharts.charts as ctc
from cutecharts.faker import Faker

# %%
# Load data
data = pd.read_csv('data/Customer-Churn-Prediction.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
newdata = data.groupby('PaymentMethod').size().rename_axis('PaymentMethodCategory').reset_index(name='Count')
newdata.head()
# Out:
#        PaymentMethodCategory  Count
# 0  Bank transfer (automatic)   1544
# 1    Credit card (automatic)   1522
# 2           Electronic check   2365
# 3               Mailed check   1612

# %%
# pie chart 
pie = ctc.Pie('Payment Method Category', # title
              width='720px',height='720px')

# set the chart options
pie.set_options(labels=list(newdata.PaymentMethodCategory), # country names as labels
                inner_radius=0,                  # inner radius set to 0
                colors=['#ee333c','#168ab5'])

# label to be shown on graph
pie.add_series(list(newdata['Count'])) 

# display the charts
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'chartXkcd':'https://cdn.jsdelivr.net/npm/chart.xkcd@1.1/dist/chart.xkcd.min'
#         }
#     });
# </script>
#
# <div id="5dabae94b38c43d19271184186865ab7" class="chart-container" style="width: 720px">
#         <svg id="chart_5dabae94b38c43d19271184186865ab7"></svg>
#     </div>
#     <script>
#         require(['chartXkcd'], function(chartXkcd) {
#             const svg_5dabae94b38c43d19271184186865ab7 = document.querySelector('#chart_5dabae94b38c43d19271184186865ab7')
#             const chart_5dabae94b38c43d19271184186865ab7 = new chartXkcd.Pie(svg_5dabae94b38c43d19271184186865ab7, {"title": "Payment Method Category", "data": {"datasets": [{"data": [1544, 1522, 2365, 1612]}], "labels": ["Bank transfer (automatic)", "Credit card (automatic)", "Electronic check", "Mailed check"]}, "options": {"innerRadius": 0, "legendPosition": 1, "dataColors": ["#ee333c", "#168ab5"]}});
#         })
#     </script>

# %%
# pie chart 
pie = ctc.Pie('Payment Method Category', # title
              width='720px',height='720px')

# set the chart options
pie.set_options(labels=list(newdata.PaymentMethodCategory), # country names as labels
                inner_radius=0.8,                  # inner radius set to 0
                colors=['#ee333c','#168ab5'])

# label to be shown on graph
pie.add_series(list(newdata['Count'])) 

# display the charts
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'chartXkcd':'https://cdn.jsdelivr.net/npm/chart.xkcd@1.1/dist/chart.xkcd.min'
#         }
#     });
# </script>
#
# <div id="702c525959394a8bb9dfaee487ab72b9" class="chart-container" style="width: 720px">
#         <svg id="chart_702c525959394a8bb9dfaee487ab72b9"></svg>
#     </div>
#     <script>
#         require(['chartXkcd'], function(chartXkcd) {
#             const svg_702c525959394a8bb9dfaee487ab72b9 = document.querySelector('#chart_702c525959394a8bb9dfaee487ab72b9')
#             const chart_702c525959394a8bb9dfaee487ab72b9 = new chartXkcd.Pie(svg_702c525959394a8bb9dfaee487ab72b9, {"title": "Payment Method Category", "data": {"datasets": [{"data": [1544, 1522, 2365, 1612]}], "labels": ["Bank transfer (automatic)", "Credit card (automatic)", "Electronic check", "Mailed check"]}, "options": {"innerRadius": 0.8, "legendPosition": 1, "dataColors": ["#ee333c", "#168ab5"]}});
#         })
#     </script>

# %%
colors=['#FFF1C9', '#F7B7A3', '#EA5F89', '#9B3192', '#57167E', '#47B39C','#00529B']

chart = ctc.Bar('Payment Method Category', width='600px', height='200px')

chart.set_options(labels=list(newdata.PaymentMethodCategory),

            x_label='Category',

            y_label='Count',   

            colors=Faker.colors
)

chart.add_series('Geners',list(newdata['Count']))

chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'chartXkcd':'https://cdn.jsdelivr.net/npm/chart.xkcd@1.1/dist/chart.xkcd.min'
#         }
#     });
# </script>
#
# <div id="9c1fbe77c3a34a808f68f297f4d9fb9e" class="chart-container" style="width: 600px">
#         <svg id="chart_9c1fbe77c3a34a808f68f297f4d9fb9e"></svg>
#     </div>
#     <script>
#         require(['chartXkcd'], function(chartXkcd) {
#             const svg_9c1fbe77c3a34a808f68f297f4d9fb9e = document.querySelector('#chart_9c1fbe77c3a34a808f68f297f4d9fb9e')
# ...

# %%
chart = ctc.Scatter("Helps to gain insights like if movies with higher budget have high popularity", width='700px', height='200px')
chart.set_options(x_label='Popularity',
                  y_label='Budget',
                  dot_size=1,
                  colors=['#47B39C']
 )
chart.add_series('Popularity vs Budget', [(z[0], z[1]) for z in list(zip(data['Churn'],data['tenure']))])
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'chartXkcd':'https://cdn.jsdelivr.net/npm/chart.xkcd@1.1/dist/chart.xkcd.min'
#         }
#     });
# </script>
#
# <div id="c36865bb94a44b76a3f24d0fd8a1f27d" class="chart-container" style="width: 700px">
#         <svg id="chart_c36865bb94a44b76a3f24d0fd8a1f27d"></svg>
#     </div>
#     <script>
#         require(['chartXkcd'], function(chartXkcd) {
#             const svg_c36865bb94a44b76a3f24d0fd8a1f27d = document.querySelector('#chart_c36865bb94a44b76a3f24d0fd8a1f27d')
# ...

# %%
chart = ctc.Radar('Cups of coffee consumed per day')
chart.set_options(
    labels=list(data['Churn']), 
    is_show_legend=True,
    legend_pos='upRight' 
    )
chart.add_series('This Week', list(data['Churn'])) 
chart.add_series('Last Week', list(data['Churn']))
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'chartXkcd':'https://cdn.jsdelivr.net/npm/chart.xkcd@1.1/dist/chart.xkcd.min'
#         }
#     });
# </script>
#
# <div id="10167c5032034903a9869957537971ec" class="chart-container" style="width: 800px">
#         <svg id="chart_10167c5032034903a9869957537971ec"></svg>
#     </div>
#     <script>
#         require(['chartXkcd'], function(chartXkcd) {
#             const svg_10167c5032034903a9869957537971ec = document.querySelector('#chart_10167c5032034903a9869957537971ec')
# ...

# %% [markdown]
# https://github.com/cutecharts/cutecharts.py<br>
# https://www.analyticsvidhya.com/blog/2021/09/hand-made-visualizations-in-python-using-cutecharts-library/<br>
# https://towardsdatascience.com/make-the-cutest-chart-in-python-visualize-your-data-with-hand-drawn-charts-f21157f76b4b
