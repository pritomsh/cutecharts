# %%
# import libraries
import pandas as pd
import cutecharts.charts as ctc

# %%
# Load data
data = pd.read_csv('data/Customer-Churn-Prediction.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
newdata = data.groupby('PaymentMethod').size().rename_axis('PaymentMethodCategory').reset_index(name='Count')
newdata.head()
# Out:
#        PaymentMethodCategory  Count
# 0  Bank transfer (automatic)   1544
# 1    Credit card (automatic)   1522
# 2           Electronic check   2365
# 3               Mailed check   1612

# %%
# pie chart 
pie = ctc.Pie('Payment Method Category', # title
              width='720px',height='720px')

# set the chart options
pie.set_options(labels=list(newdata.PaymentMethodCategory), # country names as labels
                inner_radius=0,                  # inner radius set to 0
                colors=['#ee333c','#168ab5'])

# label to be shown on graph
pie.add_series(list(newdata['Count'])) 

# display the charts
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'chartXkcd':'https://cdn.jsdelivr.net/npm/chart.xkcd@1.1/dist/chart.xkcd.min'
#         }
#     });
# </script>
#
# <div id="44f8b3fb08cd40a79a29f75d17597d05" class="chart-container" style="width: 720px">
#         <svg id="chart_44f8b3fb08cd40a79a29f75d17597d05"></svg>
#     </div>
#     <script>
#         require(['chartXkcd'], function(chartXkcd) {
#             const svg_44f8b3fb08cd40a79a29f75d17597d05 = document.querySelector('#chart_44f8b3fb08cd40a79a29f75d17597d05')
#             const chart_44f8b3fb08cd40a79a29f75d17597d05 = new chartXkcd.Pie(svg_44f8b3fb08cd40a79a29f75d17597d05, {"title": "Payment Method Category", "data": {"datasets": [{"data": [1544, 1522, 2365, 1612]}], "labels": ["Bank transfer (automatic)", "Credit card (automatic)", "Electronic check", "Mailed check"]}, "options": {"innerRadius": 0, "legendPosition": 1, "dataColors": ["#ee333c", "#168ab5"]}});
#         })
#     </script>

# %%
df_year = df['release_year'].value_counts().reset_index().sort_values(by='index', ascending=False)[:5].rename(columns={'index':'release_year','release_year':'Count'})
chart = ctc.Pie('Top 5 years', width='600px', height='300px')
chart.set_options(labels=list(df_year['release_year']), inner_radius=0.8)
chart.add_series(list(df_year['Count']))
chart.render_notebook()

# %%
# pie chart 
pie = ctc.Pie('Payment Method Category', # title
              width='720px',height='720px')

# set the chart options
pie.set_options(labels=list(newdata.PaymentMethodCategory), # country names as labels
                inner_radius=0.8,                  # inner radius set to 0
                colors=['#ee333c','#168ab5'])

# label to be shown on graph
pie.add_series(list(newdata['Count'])) 

# display the charts
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'chartXkcd':'https://cdn.jsdelivr.net/npm/chart.xkcd@1.1/dist/chart.xkcd.min'
#         }
#     });
# </script>
#
# <div id="ecc92ea633634cd6b2b875a208074e7a" class="chart-container" style="width: 720px">
#         <svg id="chart_ecc92ea633634cd6b2b875a208074e7a"></svg>
#     </div>
#     <script>
#         require(['chartXkcd'], function(chartXkcd) {
#             const svg_ecc92ea633634cd6b2b875a208074e7a = document.querySelector('#chart_ecc92ea633634cd6b2b875a208074e7a')
#             const chart_ecc92ea633634cd6b2b875a208074e7a = new chartXkcd.Pie(svg_ecc92ea633634cd6b2b875a208074e7a, {"title": "Payment Method Category", "data": {"datasets": [{"data": [1544, 1522, 2365, 1612]}], "labels": ["Bank transfer (automatic)", "Credit card (automatic)", "Electronic check", "Mailed check"]}, "options": {"innerRadius": 0.8, "legendPosition": 1, "dataColors": ["#ee333c", "#168ab5"]}});
#         })
#     </script>

# %%
from cutecharts.faker import Faker
colors=['#FFF1C9', '#F7B7A3', '#EA5F89', '#9B3192', '#57167E', '#47B39C','#00529B']

chart = ctc.Bar('Top Movie Geners', width='600px', height='200px')

chart.set_options(labels=list(newdata.PaymentMethodCategory),

            x_label='Drama',

            y_label='Count',
            
                

colors=Faker.colors

)

chart.add_series('Geners',list(newdata['Count']))

chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'chartXkcd':'https://cdn.jsdelivr.net/npm/chart.xkcd@1.1/dist/chart.xkcd.min'
#         }
#     });
# </script>
#
# <div id="62e7ccefbbc04523a7cab003c271cb48" class="chart-container" style="width: 600px">
#         <svg id="chart_62e7ccefbbc04523a7cab003c271cb48"></svg>
#     </div>
#     <script>
#         require(['chartXkcd'], function(chartXkcd) {
#             const svg_62e7ccefbbc04523a7cab003c271cb48 = document.querySelector('#chart_62e7ccefbbc04523a7cab003c271cb48')
#             const chart_62e7ccefbbc04523a7cab003c271cb48 = new chartXkcd.Bar(svg_62e7ccefbbc04523a7cab003c271cb48, {"title": "Top Movie Geners", "data": {"datasets": [{"label": "Geners", "data": [1544, 1522, 2365, 1612]}], "labels": ["Bank transfer (automatic)", "Credit card (automatic)", "Electronic check", "Mailed check"]}, "xLabel": "Drama", "yLabel": "Count", "options": {"yTickCount": 3, "dataColors": ["#c23531", "#2f4554", "#61a0a8", "#d48265", "#749f83", "#ca8622", "#bda29a"]}});
#         })
#     </script>

# %%
https://github.com/cutecharts/cutecharts.py
https://www.analyticsvidhya.com/blog/2021/09/hand-made-visualizations-in-python-using-cutecharts-library/
https://towardsdatascience.com/make-the-cutest-chart-in-python-visualize-your-data-with-hand-drawn-charts-f21157f76b4b
